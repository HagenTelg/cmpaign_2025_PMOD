# %%
prefix = '/Users/htelg/' 
p2fld = pl.Path(f'{prefix}/nfs/grad/campaign/frc/2025/AOD/')

# %%
version = '0.5'

p2f = pl.Path(f'{prefix}/nfs/grad/campaign/frc/2025/AOD/US_NOAA_MFR#9/netcdf/v{version}/')
ds = xr.open_mfdataset(p2f.glob('*.nc'))
ds649v5 = ds

p2f = pl.Path(f'{prefix}/nfs/grad/campaign/frc/2025/AOD/US_NOAA_MFR#8/netcdf/v{version}/')
ds = xr.open_mfdataset(p2f.glob('*.nc'))
ds648v5 = ds
# Out:
# /var/folders/f4/dl3whmyd1rj_9smbyhmyqyj1h26f40/T/ipykernel_96768/3799095877.py:4: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(p2f.glob('*.nc'))
# /var/folders/f4/dl3whmyd1rj_9smbyhmyqyj1h26f40/T/ipykernel_96768/3799095877.py:8: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
# ...

# %%
version = '0.4'

p2f = pl.Path(f'{prefix}/nfs/grad/campaign/frc/2025/AOD/US_NOAA_MFR#9/netcdf/v{version}/')
ds = xr.open_mfdataset(p2f.glob('*.nc'))
ds649v4 = ds

p2f = pl.Path(f'{prefix}/nfs/grad/campaign/frc/2025/AOD/US_NOAA_MFR#8/netcdf/v{version}/')
ds = xr.open_mfdataset(p2f.glob('*.nc'))
ds648v4 = ds
# Out:
# /var/folders/f4/dl3whmyd1rj_9smbyhmyqyj1h26f40/T/ipykernel_96768/2134879772.py:4: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(p2f.glob('*.nc'))
# /var/folders/f4/dl3whmyd1rj_9smbyhmyqyj1h26f40/T/ipykernel_96768/2134879772.py:8: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
# ...

# %% [markdown]
# # 648

# %%
# %matplotlib widget

# %%
f,a = plt.subplots()
wl = 500
alpha = 0.4
aod = ds648v5.aod.sel(channel = wl)
aod.plot(ax = a, label = 'v5')
if 1:
    col = a.get_lines()[-1].get_color()
    uc = ds648v5.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)

aod = ds648v4.aod.sel(channel = wl)
aod.plot(ax = a, label = 'v4')
if 0:
    col = a.get_lines()[-1].get_color()
    uc = ds648v4.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)


a.legend(fontsize = 'x-small')
a.set_ylim(-0.01, 0.05)
# f.show()
# Out:
# (-0.01, 0.05)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f,a = plt.subplots()
wl = 870
alpha = 0.4
aod = ds648v5.aod.sel(channel = wl)
aod.plot(ax = a, label = 'v5')
if 1:
    col = a.get_lines()[-1].get_color()
    uc = ds648v5.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)

aod = ds648v4.aod.sel(channel = wl)
aod.plot(ax = a, label = 'v4')
if 0:
    col = a.get_lines()[-1].get_color()
    uc = ds648v4.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)


a.legend(fontsize = 'x-small')
a.set_ylim(-0.01, 0.05)
# f.show()
# Out:
# (-0.01, 0.05)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # 649

# %%
f,a = plt.subplots()
wl = 500
alpha = 0.4
aod = ds649v5.aod.sel(channel = wl)
aod.plot(ax = a, label = 'v5')
if 1:
    col = a.get_lines()[-1].get_color()
    uc = ds649v5.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)

aod = ds649v4.aod.sel(channel = wl)
aod.plot(ax = a, label = 'v4')
if 0:
    col = a.get_lines()[-1].get_color()
    uc = ds649v4.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)


a.legend(fontsize = 'small')
a.set_ylim(-0.01, 0.05)
f.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f,a = plt.subplots()
wl = 415
alpha = 0.4
aod = ds649v5.aod.sel(channel = wl)
aod.plot(ax = a, label = 'v5')
if 1:
    col = a.get_lines()[-1].get_color()
    uc = ds649v5.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)

aod = ds649v4.aod.sel(channel = wl)
aod.plot(ax = a, label = 'v4')
if 0:
    col = a.get_lines()[-1].get_color()
    uc = ds649v4.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)


a.legend(fontsize = 'small')
a.set_ylim(-0.01, 0.05)
f.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f,a = plt.subplots()
wl = 670
alpha = 0.4
aod = ds649v5.aod.sel(channel = wl)
aod.plot(ax = a, label = 'v5')
if 1:
    col = a.get_lines()[-1].get_color()
    uc = ds649v5.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)

aod = ds649v4.aod.sel(channel = wl)
aod.plot(ax = a, label = 'v4')
if 0:
    col = a.get_lines()[-1].get_color()
    uc = ds649v4.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)


a.legend(fontsize = 'small')
a.set_ylim(-0.01, 0.05)
f.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f,a = plt.subplots()
wl = 870
alpha = 0.4
aod = ds649v5.aod.sel(channel = wl)
aod.plot(ax = a, label = 'v5')
if 1:
    col = a.get_lines()[-1].get_color()
    uc = ds649v5.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)

aod = ds649v4.aod.sel(channel = wl)
aod.plot(ax = a, label = 'v4')
if 0:
    col = a.get_lines()[-1].get_color()
    uc = ds649v4.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)


a.legend(fontsize = 'x-small')
a.set_ylim(-0.01, 0.05)
f.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f,a = plt.subplots()
wl = 1625
alpha = 0.4
aod = ds649v5.aod.sel(channel = wl)
aod.plot(ax = a, label = 'v5')
if 1:
    col = a.get_lines()[-1].get_color()
    uc = ds649v5.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)

aod = ds649v4.aod.sel(channel = wl)
aod.plot(ax = a, label = 'v4')
if 0:
    col = a.get_lines()[-1].get_color()
    uc = ds649v4.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)


a.legend(fontsize = 'x-small')
a.set_ylim(-0.01, 0.05)
f.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
