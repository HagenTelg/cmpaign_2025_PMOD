# %%
prefix = '/Users/htelg/' 
p2fld = pl.Path(f'{prefix}/nfs/grad/campaign/frc/2025/AOD/')

# %%
fl = list(p2fld.glob('**/*'))
for f in fl:
    if 'JP_JMA_POM' in f.as_posix():
        continue
    if 'SE_SMHI_PFR' in f.as_posix():
        continue
    if 'US_NOAA_MFR' in f.as_posix():
        continue
    if 'DE_PTB_SSIM' in f.as_posix():
        continue
    if 'ES_UV_POM' in f.as_posix():
        continue
    if 'IT_CNR.ISAC_POM' in f.as_posix():
        continue
    print(f)
# Out:
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/DE_PTB_CAS-IR
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/ES_GOA.UVa_CE
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/DE_DWD_PSR#04
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/DE_DWD_PFR-F
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/ES_CIEMAT_SP02-L
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/ES_CIEMAT_BTS
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/DE_PTB_CAS
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/ES_AEMET_CE
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/US_NOAA_HSR1
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/FR_LOA.UoL_CE
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/DE_PTB_CAS-VisNIR
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/DE_DWD_PFR
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/CY_ECOE_MTS
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/CN_CMA_CW193
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/ES_AEMET_CLT
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/ES_UVa_MTS
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/FI_FMI_PFR
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/DE_PTB_CAS/Comments.txt
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/DE_PTB_CAS/2025-10-08 PTB_spectral_irradiance.zip
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/DE_PTB_CAS/2025-09-21 PTB_spectral_irradiance.zip
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/DE_PTB_CAS/2025-09-20 PTB_spectral_irradiance.zip
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/DE_PTB_CAS/2025-09-23 PTB_spectral_irradiance.zip
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/DE_PTB_CAS/2025-09-29 PTB_spectral_irradiance.zip
# /Users/htelg/nfs/grad/campaign/frc/2025/AOD/DE_PTB_CAS/2025-09-28 PTB_spectral_irradiance.zip

# %%
p2f = '/Users/htelg/nfs/grad/campaign/frc/2025/AOD/IT_CNR.ISAC_POM/IT_TOR_PREDE_20251017.aod'
df = pd.read_csv(p2f, skiprows=1)

# %%
df
# Out:
#      yyyy  mm  dd  HH_UTC  MM  SS  aod_340  aod_400  aod_500  aod_675  ...  \
# 0    2025  10  17       6  58   0   0.0380   0.0352   0.0316   0.0302  ...
# 1    2025  10  17       7   2  58   0.0374   0.0348   0.0315   0.0302  ...
# 2    2025  10  17       7   3  58   0.0376   0.0349   0.0314   0.0302  ...
# 3    2025  10  17       7   4  58   0.0374   0.0347   0.0314   0.0302  ...
# 4    2025  10  17       7   5  58   0.0371   0.0342   0.0310   0.0301  ...
# ..    ...  ..  ..     ...  ..  ..      ...      ...      ...      ...  ...
# 291  2025  10  17      15   5   0   0.0908   0.0752   0.0593   0.0470  ...
# 292  2025  10  17      15  13   0   0.0941   0.0780   0.0611   0.0477  ...
# 293  2025  10  17      15  13  59   0.0944   0.0782   0.0611   0.0476  ...
# 294  2025  10  17      15  15   0   0.0938   0.0775   0.0606   0.0472  ...
# 295  2025  10  17      15  16   0   0.0933   0.0772   0.0601   0.0468  ...
#
#      Angstrom_Turbidity_Coefficient_IR  U_aod_340  U_aod_400  U_aod_500  \
# 0                               0.0255          0          0          0
# 1                               0.0260          0          0          0
# 2                               0.0262          0          0          0
# 3                               0.0263          0          0          0
# 4                               0.0265          0          0          0
# ..                                 ...        ...        ...        ...
# 291                             0.0352          0          0          0
# 292                             0.0342          0          0          0
# 293                             0.0339          0          0          0
# 294                             0.0334          0          0          0
# 295                             0.0330          0          0          0
#
#      U_aod_675  U_aod_870  U_aod_1020  Atmospheric_pressure  Ozone       NO2
# 0            0          0           0                0.8285    300  0.000218
# 1            0          0           0                0.8285    300  0.000218
# 2            0          0           0                0.8285    300  0.000218
# 3            0          0           0                0.8285    300  0.000218
# 4            0          0           0                0.8285    300  0.000218
# ..         ...        ...         ...                   ...    ...       ...
# 291          0          0           0                0.8285    300  0.000218
# 292          0          0           0                0.8285    300  0.000218
# 293          0          0           0                0.8285    300  0.000218
# 294          0          0           0                0.8285    300  0.000218
# 295          0          0           0                0.8285    300  0.000218
#
# [296 rows x 27 columns]

# %%
import helpers

# %%
reload(helpers)
# Out:
# <module 'helpers' from '/Users/htelg/projects/cmpaign_2025_PMOD/helpers.py'>

# %%
p2f = list(pl.Path('/Users/htelg/nfs/grad/campaign/frc/2025/AOD/IT_CNR.ISAC_POM/').glob('*.aod'))  #ES_UV_POM/SP_UVEG_PREDE_20251008.aod'
ds = helpers.read_IT_CNR_ISAC_POM(p2f) 
ds_IT_CNR_ISAC_POM = ds

# %%
p2f = list(pl.Path('/Users/htelg/nfs/grad/campaign/frc/2025/AOD/ES_UV_POM/').glob('*.aod'))  #ES_UV_POM/SP_UVEG_PREDE_20251008.aod'
ds = helpers.read_ES_UV_POM(p2f) 
ds_ES_UV_POM = ds

# %%
p2f = list(pl.Path('/Users/htelg/nfs/grad/campaign/frc/2025/AOD/DE_PTB_SSIM/').glob('*.csv')) #2025-09-28_SSIM_Data_SN160.csv'
ds = helpers.read_DE_PTB_SSIM(p2f)
ds_DE_PTB_SSIM = ds

# %%
p2f = pl.Path(f'{prefix}/nfs/grad/campaign/frc/2025/AOD/US_NOAA_MFR#9/netcdf/v0.4/')
ds = xr.open_mfdataset(p2f.glob('*.nc'))
ds649 = ds
# Out:
# /var/folders/f4/dl3whmyd1rj_9smbyhmyqyj1h26f40/T/ipykernel_47165/3625867082.py:2: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(p2f.glob('*.nc'))

# %%
p2f = pl.Path(f'{prefix}/nfs/grad/campaign/frc/2025/AOD/US_NOAA_MFR#8/netcdf/v0.4/')
ds = xr.open_mfdataset(p2f.glob('*.nc'))
ds648 = ds
# Out:
# /var/folders/f4/dl3whmyd1rj_9smbyhmyqyj1h26f40/T/ipykernel_47165/2166663504.py:2: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(p2f.glob('*.nc'))

# %%
p2f = list(pl.Path(f'{prefix}/nfs/grad/campaign/frc/2025/AOD/JP_JMA_POM/').glob('*.aod'))
ds = helpers.read_JP_JMA_POM(p2f)
ds_jp_jma_pom = ds
# ds

# %%
p2f = list(pl.Path(f'{prefix}/nfs/grad/campaign/frc/2025/AOD/SE_SMHI_PFR/').glob('*.aod'))

ds = helpers.read_SE_SMHI_PFR(p2f)
ds_se_smhi_pfr = ds

# %%
# %matplotlib widget

# %%
f,a = plt.subplots()
for c in ds648.channel:
    ds648.aod.sel(channel = c).plot(ax = a, label = int(c))
a.legend(fontsize = 'x-small')
# a.set_ylim(-0.01, 0.05)
f.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f,a = plt.subplots()
for c in ds649.channel:
    ds649.aod.sel(channel = c).plot(ax = a, label = int(c))
a.legend(fontsize = 'x-small')
# a.set_ylim(-0.01, 0.05)
f.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f,a = plt.subplots()
for c in ds648.channel:
    ds648.od_rayleigh.sel(channel = c).plot(ax = a, label = int(c))
a.legend(fontsize = 'x-small')
# a.set_ylim(-0.01, 0.05)
f.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f,a = plt.subplots()
for c in ds648.channel:
    ds648.od_rayleigh.sel(channel = c).plot(ax = a, label = int(c))
a.legend(fontsize = 'x-small')
# a.set_ylim(-0.01, 0.05)
f.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f,a = plt.subplots()
for c in ds648.channel:
    ds648.od_rayleigh.sel(channel = c).plot(ax = a, label = int(c))
a.legend(fontsize = 'x-small')
# a.set_ylim(-0.01, 0.05)
f.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ds648
# Out:
# <xarray.Dataset> Size: 51MB
# Dimensions:                   (datetime: 99421, channel: 6)
# Coordinates:
#   * datetime                  (datetime) datetime64[ns] 795kB 2025-09-25 ... ...
#   * channel                   (channel) int64 48B 415 500 670 870 940 1625
#     quantile                  float64 8B 0.9
# Data variables: (12/19)
#     aod                       (datetime, channel) float64 5MB dask.array<chunksize=(4297, 6), meta=np.ndarray>
#     cloud_flag                (datetime) int8 99kB dask.array<chunksize=(4297,), meta=np.ndarray>
#     precipitable_water        (datetime) float64 795kB dask.array<chunksize=(4297,), meta=np.ndarray>
#     transmission              (datetime, channel) float64 5MB dask.array<chunksize=(4297, 6), meta=np.ndarray>
#     global_horizontal         (datetime, channel) float64 5MB dask.array<chunksize=(4297, 6), meta=np.ndarray>
#     diffuse_horizontal        (datetime, channel) float64 5MB dask.array<chunksize=(4297, 6), meta=np.ndarray>
#     ...                        ...
#     cosine_calibraion_direct  (datetime, channel) float64 5MB dask.array<chunksize=(4297, 6), meta=np.ndarray>
#     solar_zenith_angle        (datetime) float64 795kB dask.array<chunksize=(4297,), meta=np.ndarray>
#     solar_azimuth_angle       (datetime) float64 795kB dask.array<chunksize=(4297,), meta=np.ndarray>
#     pressure                  (datetime) float64 795kB dask.array<chunksize=(4297,), meta=np.ndarray>
#     temperature               (datetime) float64 795kB dask.array<chunksize=(4297,), meta=np.ndarray>
#     ozone_data                (datetime) float64 795kB dask.array<chunksize=(4297,), meta=np.ndarray>
# Attributes:
#     description:           Spectral AOD, downwelling fluxes, and precipitable...
#     site_longitude:        9.838257
#     site_latitude:         46.807251
#     serial_no:             648
#     instrument_type:       mfrsr
#     input_files:           /Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/2025/m...
#     processing_timestamp:  2025-12-16 14:28:18.215268
#     product_version:       0.1

# %%
f,a = plt.subplots()
wl = 500
alpha = 0.4
aod = ds648.aod.sel(channel = wl)
aod.plot(ax = a, label = 'ds648')
if 0:
    col = a.get_lines()[-1].get_color()
    uc = ds648.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)

aod = ds649.aod.sel(channel = wl)
aod.plot(ax = a, label = 'ds649')
if 1:
    col = a.get_lines()[-1].get_color()
    uc = ds649.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)

ds_jp_jma_pom.aod.sel(channel = wl).plot(ax = a, label = 'jp_jma_pom')

wlt = ds_se_smhi_pfr.channel.isel(channel = abs(ds_se_smhi_pfr.channel-wl).argmin())
ds_se_smhi_pfr.aod.sel(channel = wlt).plot(ax = a, label = f'se_smhi_pfr ({float(wlt)})')
ds_DE_PTB_SSIM.aod.sel(channel = wl).plot(ax = a, label = 'DE_PTB_SSIM')
ds_ES_UV_POM.aod.sel(channel = wl).plot(ax = a, label = 'ES_UV_POM')
ds_IT_CNR_ISAC_POM.aod.sel(channel = wl).plot(ax = a, label = 'IT_CNR_ISAC_POM')
a.legend(fontsize = 'x-small')
a.set_ylim(-0.01, 0.05)
f.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f,a = plt.subplots()
wl = 415
alpha = 0.4
aod = ds648.aod.sel(channel = wl)
aod.plot(ax = a, label = 'ds648')
if 0:
    col = a.get_lines()[-1].get_color()
    uc = ds648.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)

aod = ds649.aod.sel(channel = wl)
aod.plot(ax = a, label = 'ds649')
if 1:
    col = a.get_lines()[-1].get_color()
    uc = ds649.aod_uncertainty.sel(channel = wl)
    a.fill_between(aod.datetime, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)
wlt = ds_jp_jma_pom.channel.isel(channel = abs(ds_jp_jma_pom.channel-wl).argmin())
ds_jp_jma_pom.aod.sel(channel = wlt).plot(ax = a, label = f'jp_jma_pom ({float(wlt)})')

wlt = ds_se_smhi_pfr.channel.isel(channel = abs(ds_se_smhi_pfr.channel-wl).argmin())
ds_se_smhi_pfr.aod.sel(channel = wlt).plot(ax = a, label = f'se_smhi_pfr ({float(wlt)})')

wlt = ds_DE_PTB_SSIM.channel.isel(channel = abs(ds_DE_PTB_SSIM.channel-wl).argmin())
ds_DE_PTB_SSIM.aod.sel(channel = wlt).plot(ax = a, label = f'DE_PTB_SSIM ({float(wlt)})')

wlt = ds_ES_UV_POM.channel.isel(channel = abs(ds_ES_UV_POM.channel-wl).argmin())
ds_ES_UV_POM.aod.sel(channel = wlt).plot(ax = a, label = f'ES_UV_POM ({float(wlt)})')

wlt = ds_IT_CNR_ISAC_POM.channel.isel(channel = abs(ds_IT_CNR_ISAC_POM.channel-wl).argmin())
ds_IT_CNR_ISAC_POM.aod.sel(channel = wlt).plot(ax = a, label = f'IT_CNR_ISAC_POM ({float(wlt)})')
a.legend(fontsize = 'x-small')


f.canvas.show()
# a.set_ylim(-0.01, 0.05)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f,a = plt.subplots()
wl = 870
ds648.aod.sel(channel = wl).plot(ax = a, label = 'ds648')
ds649.aod.sel(channel = wl).plot(ax = a, label = 'ds649')
wlt = ds_jp_jma_pom.channel.isel(channel = abs(ds_jp_jma_pom.channel-wl).argmin())
ds_jp_jma_pom.aod.sel(channel = wlt).plot(ax = a, label = f'jp_jma_pom ({float(wlt)})')

wlt = ds_se_smhi_pfr.channel.isel(channel = abs(ds_se_smhi_pfr.channel-wl).argmin())
ds_se_smhi_pfr.aod.sel(channel = wlt).plot(ax = a, label = f'se_smhi_pfr ({float(wlt)})')

wlt = ds_DE_PTB_SSIM.channel.isel(channel = abs(ds_DE_PTB_SSIM.channel-wl).argmin())
ds_DE_PTB_SSIM.aod.sel(channel = wlt).plot(ax = a, label = f'DE_PTB_SSIM ({float(wlt)})')

wlt = ds_ES_UV_POM.channel.isel(channel = abs(ds_ES_UV_POM.channel-wl).argmin())
ds_ES_UV_POM.aod.sel(channel = wlt).plot(ax = a, label = f'ES_UV_POM ({float(wlt)})')

wlt = ds_IT_CNR_ISAC_POM.channel.isel(channel = abs(ds_IT_CNR_ISAC_POM.channel-wl).argmin())
ds_IT_CNR_ISAC_POM.aod.sel(channel = wlt).plot(ax = a, label = f'IT_CNR_ISAC_POM ({float(wlt)})')
a.legend(fontsize = 'x-small')


f.canvas.show()
# a.set_ylim(-0.01, 0.05)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
a.set_ylim(-0.01, 0.05)
a.set_title(f'wl ~ {wl}')
# Out:
# Text(0.5, 1.0, 'wl ~ 415')

# %%
ds_jp_jma_pom
# Out:
# <xarray.Dataset> Size: 220kB
# Dimensions:   (datetime: 2494, channel: 10)
# Coordinates:
#   * datetime  (datetime) datetime64[ns] 20kB 2025-09-28T06:31:00 ... 2025-10-...
#   * channel   (channel) int64 80B 340 380 400 500 675 870 1020 1225 1627 2200
# Data variables:
#     aod       (datetime, channel) float64 200kB 0.0352 0.035 ... 0.0068 0.0298

# %%
f,a = plt.subplots()
wl = 500
ds648.aod.sel(channel = wl).plot(ax = a, label = 'ds648')
ds649.aod.sel(channel = wl).plot(ax = a, label = 'ds649')
ds_jp_jma_pom.aod.sel(channel = wl).plot(ax = a, label = 'jp_jma_pom')
ds_se_smhi_pfr.aod.isel(channel = abs(ds_se_smhi_pfr.channel-wl).argmin()).plot(ax = a, label = 'se_smhi_pfr')
ds_DE_PTB_SSIM.aod.sel(channel = wl).plot(ax = a, label = 'DE_PTB_SSIM')
ds_ES_UV_POM.aod.sel(channel = wl).plot(ax = a, label = 'ES_UV_POM')
ds_IT_CNR_ISAC_POM.aod.sel(channel = wl).plot(ax = a, label = 'IT_CNR_ISAC_POM')
a.legend(fontsize = 'x-small')
a.set_ylim(-0.01, 0.05)
f.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f,a = plt.subplots()
wl = 400
ds648.aod.sel(channel = wl).plot(ax = a, label = 'ds648')
ds649.aod.sel(channel = wl).plot(ax = a, label = 'ds649')
ds_jp_jma_pom.aod.sel(channel = wl).plot(ax = a, label = 'jp_jma_pom')
ds_se_smhi_pfr.aod.isel(channel = abs(ds_se_smhi_pfr.channel-wl).argmin()).plot(ax = a, label = 'se_smhi_pfr')
ds_DE_PTB_SSIM.aod.sel(channel = wl).plot(ax = a, label = 'DE_PTB_SSIM')
ds_ES_UV_POM.aod.sel(channel = wl).plot(ax = a, label = 'ES_UV_POM')
ds_IT_CNR_ISAC_POM.aod.sel(channel = wl).plot(ax = a, label = 'IT_CNR_ISAC_POM')
a.legend(fontsize = 'x-small')
a.set_ylim(-0.01, 0.05)
f.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/py12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 400
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/py12/lib/python3.12/site-packages/xarray/core/indexes.py:861, in PandasIndex.sel(self, labels, method, tolerance)
#     860 try:
# --> 861     indexer = self.index.get_loc(label_value)
#     862 except KeyError as e:
#
# File ~/miniconda3/envs/py12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#
# KeyError: 400
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[196], line 3
#       1 f,a = plt.subplots()
#       2 wl = 400
# ----> 3 ds648.aod.sel(channel = wl).plot(ax = a, label = 'ds648')
#       4 ds649.aod.sel(channel = wl).plot(ax = a, label = 'ds649')
#       5 ds_jp_jma_pom.aod.sel(channel = wl).plot(ax = a, label = 'jp_jma_pom')
#
# File ~/miniconda3/envs/py12/lib/python3.12/site-packages/xarray/core/dataarray.py:1717, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1601 def sel(
#    1602     self,
#    1603     indexers: Mapping[Any, Any] | None = None,
#    (...)   1607     **indexers_kwargs: Any,
#    1608 ) -> Self:
#    1609     """Return a new DataArray whose data is given by selecting index
#    1610     labels along the specified dimension(s).
#    1611
#    (...)   1715     Dimensions without coordinates: points
#    1716     """
# -> 1717     ds = self._to_temp_dataset().sel(
#    1718         indexers=indexers,
#    1719         drop=drop,
#    1720         method=method,
#    1721         tolerance=tolerance,
#    1722         **indexers_kwargs,
#    1723     )
#    1724     return self._from_temp_dataset(ds)
#
# File ~/miniconda3/envs/py12/lib/python3.12/site-packages/xarray/core/dataset.py:2988, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2920 """Returns a new dataset with each array indexed by tick labels
#    2921 along the specified dimension(s).
#    2922
#    (...)   2985
#    2986 """
#    2987 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2988 query_results = map_index_queries(
#    2989     self, indexers=indexers, method=method, tolerance=tolerance
#    2990 )
#    2992 if drop:
#    2993     no_scalar_variables = {}
#
# File ~/miniconda3/envs/py12/lib/python3.12/site-packages/xarray/core/indexing.py:201, in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     199         results.append(IndexSelResult(labels))
#     200     else:
# --> 201         results.append(index.sel(labels, **options))
#     203 merged = merge_sel_results(results)
#     205 # drop dimension coordinates found in dimension indexers
#     206 # (also drop multi-index if any)
#     207 # (.sel() already ensures alignment)
#
# File ~/miniconda3/envs/py12/lib/python3.12/site-packages/xarray/core/indexes.py:863, in PandasIndex.sel(self, labels, method, tolerance)
#     861             indexer = self.index.get_loc(label_value)
#     862         except KeyError as e:
# --> 863             raise KeyError(
#     864                 f"not all values found in index {coord_name!r}. "
#     865                 "Try setting the `method` keyword argument (example: method='nearest')."
#     866             ) from e
#     868 elif label_array.dtype.kind == "b":
#     869     indexer = label_array
#
# KeyError: "not all values found in index 'channel'. Try setting the `method` keyword argument (example: method='nearest')."

# %%
f,a = plt.subplots()
ds_ES_UV_POM.aod.sel(channel = 500).plot(ax = a)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ds_se_smhi_pfr.aod.isel(channel = abs(ds_se_smhi_pfr.channel-wl).argmin()).plot(ax = a, label = f'se_smhi_pfr (')

# %%
bla
# Out:
# <xarray.DataArray 'aod' (datetime: 7696)> Size: 62kB
# array([0.1676, 0.0691, 0.0344, ..., 0.0554, 0.0533, 0.0543], shape=(7696,))
# Coordinates:
#   * datetime  (datetime) datetime64[ns] 62kB 2025-09-28T06:12:00 ... 2025-10-...
#     channel   float64 8B 499.5

# %%
f,a = plt.subplots()
ds_jp_jma_pom.aod.plot.line(x = 'datetime')
a.set_ylim(-0.01,0.05)
# Out:
# (-0.01, 0.05)

# %%
f,a = plt.subplots()
ds.aod.plot.line(x = 'datetime', ax = a)
a.set_ylim(-0.01, 0.05)
# Out:
# (-0.01, 0.05)

# %%
ds_jp_jma_pom.channel
# Out:
# <xarray.DataArray 'channel' (channel: 10)> Size: 80B
# array([ 340,  380,  400,  500,  675,  870, 1020, 1225, 1627, 2200])
# Coordinates:
#   * channel  (channel) int64 80B 340 380 400 500 675 870 1020 1225 1627 2200

# %%
ds_se_smhi_pfr.channel
# Out:
# <xarray.DataArray 'channel' (channel: 4)> Size: 32B
# array([368.4, 412.8, 499.5, 862.3])
# Coordinates:
#   * channel  (channel) float64 32B 368.4 412.8 499.5 862.3

# %%
f,a = plt.subplots()
ds_se_smhi_pfr.aod.sel(channel = 862.3).plot(ax = a, label = p2f.name)
ds_jp_jma_pom.aod.sel(channel = 870).plot(ax = a, label = 'ds_jp_jma_pom')
dni648.aod.sel(channel = 870).plot(ax = a, label = '648')
dni649.aod.sel(channel = 870).plot(ax = a, label = '649')

a.legend()
a.set_ylim(-0.01, 0.04)
# Out:
# (-0.01, 0.04)

# %%
f,a = plt.subplots()
# ds_se_smhi_pfr.aod.sel(channel = 862.3).plot(ax = a, label = p2f.name)
a._get_lines.get_next_color()
ds_jp_jma_pom.aod.sel(channel = 675).plot(ax = a, label = 'ds_jp_jma_pom')
dni648.aod.sel(channel = 670).plot(ax = a, label = '648')
dni649.aod.sel(channel = 670).plot(ax = a, label = '649')

a.legend()
a.set_ylim(-0.01, 0.04)
# Out:
# (-0.01, 0.04)

# %%
f,a = plt.subplots()
ds_se_smhi_pfr.aod.sel(channel = 499.5).plot(ax = a, label = 'se_smhi_pfr')
ds_jp_jma_pom.aod.sel(channel = 500).plot(ax = a, label = 'ds_jp_jma_pom')
dni648.aod.sel(channel = 500).plot(ax = a, label = '648')
dni649.aod.sel(channel = 500).plot(ax = a, label = '649')
a.legend()
a.set_ylim(-0.01, 0.04)
# Out:
# (-0.01, 0.04)

# %%
f,a = plt.subplots()#, gridspec_kw={'hspace': 0})
# a = aa[0]
ds_se_smhi_pfr.aod.sel(channel = 412.8).plot(ax = a, label = p2f.name)
ds_jp_jma_pom.aod.sel(channel = 400).plot(ax = a, label = 'ds_jp_jma_pom')
dni648.aod.sel(channel = 415).plot(ax = a, label = '648')
dni649.aod.sel(channel = 415).plot(ax = a, label = '649')

a.legend()
a.set_ylim(-0.01, 0.04)
# Out:
# (-0.01, 0.04)

# %%
dni648.od_ozone.plot.line(x = 'datetime')
# Out:
# [<matplotlib.lines.Line2D at 0x7f2cd06e6450>,
#  <matplotlib.lines.Line2D at 0x7f2cd065b290>,
#  <matplotlib.lines.Line2D at 0x7f2ccaf93140>,
#  <matplotlib.lines.Line2D at 0x7f2cd0738800>,
#  <matplotlib.lines.Line2D at 0x7f2cd06e63f0>]
