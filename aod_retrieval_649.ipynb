# %%
import atmPy.radiation.retrievals.langley_calibration as atmlc

# %%
import helpers

# %% [markdown]
# # AOD

# %%
# check what the current version are
# '/Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/2025/mfrsr/.cal/v0.2/

# %%
prefix = '/Users/htelg'
overwrite = True
version = '1.0' #version of this prodcut
version_langleys = '0.6'
version_in = '0.2' # version of the cosine corrected files
serial_no = 649
# pwv_corrfct = 1.42
p2fld_out = pl.Path(f'{prefix}/nfs/grad/campaign/frc/2025/AOD/US_NOAA_MFR_{str(serial_no)[-1]}/netcdf/v{version}/')
p2fld_mfrsr = pl.Path(f'{prefix}/nfs/grad/Inst/MFR/Campaign/frc/2025/mfrsr/{serial_no}.cal/v{version_in}/2025')
p2fld_met = pl.Path(f'{prefix}/nfs/grad/campaign/frc/2025/MetaData.netcdf/')
"""changelog
------------
== v0.2== 
- subtruct aod from 940 by extrapolating with angstrom exponent
== v0.3 ==
- use aeronet precipitable water instead
== v0.4 ==
- added uncertainties
== v0.5 ==
- langleys slightly different due to improved airmass
- removed 940 channel
== v0.6 ==
- cosine correction fixed
== v0.7 ==
- precipitable water is back in the mix. This also effects the 1625 channel. (lets see if my change in cosine correction helped)
== v0.8 ==
- precipitable water vapor got a correction term based on a sidebyside comparison with Aeronet
== v0.9 ==
- pwv is now self calibrated
== v1.0 ==
- This will be the first official version
- many attributes are added/improved
- angstrom exponent added (including uncertainty)
"""
# Out:
# 'changelog\n------------\n== v0.2== \n- subtruct aod from 940 by extrapolating with angstrom exponent\n== v0.3 ==\n- use aeronet precipitable water instead\n== v0.4 ==\n- added uncertainties\n== v0.5 ==\n- langleys slightly different due to improved airmass\n- removed 940 channel\n== v0.6 ==\n- cosine correction fixed\n== v0.7 ==\n- precipitable water is back in the mix. This also effects the 1625 channel. (lets see if my change in cosine correction helped)\n== v0.8 ==\n- precipitable water vapor got a correction term based on a sidebyside comparison with Aeronet\n== v0.9 ==\n- pwv is now self calibrated\n== v1.0 ==\n- This will be the first official version\n- many attributes are added/improved\n- angstrom exponent added (including uncertainty)\n'

# %% [markdown]
# ## langley calibration

# %% [markdown]
# ### load calibration

# %%
p2f = f'data/V0_simple_{serial_no}_v{version_langleys}.nc'
V0 = xr.open_dataset(p2f)
V0.attrs['path2file'] = p2f

# %%
V0.sel(wavelength = 1625).compute()
# Out:
# <xarray.Dataset> Size: 56B
# Dimensions:                              ()
# Coordinates:
#     wavelength                           int64 8B 1625
# Data variables:
#     V0                                   float64 8B 516.8
#     V0_std                               float64 8B 1.708
#     number_of_cals                       int64 8B 9
#     one_sided_upper_bound_factor_95conf  float64 8B 1.711
#     OD_uncertainty                       float64 8B 0.01065
#     V0_stderr                            float64 8B 0.001489
# Attributes:
#     path2file:  data/V0_simple_649_v0.6.nc

# %%
V0.compute()
# Out:
# <xarray.Dataset> Size: 336B
# Dimensions:                              (wavelength: 6)
# Coordinates:
#   * wavelength                           (wavelength) int64 48B 415 500 ... 1625
# Data variables:
#     V0                                   (wavelength) float64 48B 3.06e+03 .....
#     V0_std                               (wavelength) float64 48B 39.0 ... 1.708
#     number_of_cals                       (wavelength) int64 48B 9 9 9 9 9 9
#     one_sided_upper_bound_factor_95conf  (wavelength) float64 48B 1.711 ... 1...
#     OD_uncertainty                       (wavelength) float64 48B 0.0268 ... ...
#     V0_stderr                            (wavelength) float64 48B 0.001134 .....
# Attributes:
#     path2file:  data/V0_simple_649_v0.6.nc

# %% [markdown]
# # look up table

# %%
fnlut = f'/Users/htelg/projects/mfrsr2pwv/data/pwd_od_lut_{serial_no}.nc'
ds_lut = xr.open_dataset(fnlut)
ds_lut.attrs.update({'path2file': fnlut})

# %% [markdown]
# # the product

# %%
import atmPy.radiation.retrievals.spectral_irradiance as atmspec
import atmPy.aerosols.physics.column_optical_properties as atmcop

# %%
reload(atmspec)
# Out:
# <module 'atmPy.radiation.retrievals.spectral_irradiance' from '/Users/htelg/prog/atm-py/atmPy/radiation/retrievals/spectral_irradiance.py'>

# %%
def make_product(fn,
                 fnmet,
                 fnlut,
                 langley_calibration,
                 serial_no,
                 version,
                verbose = False,
                pwv_source = '940'):
    out = {}
    ds = xr.open_dataset(fn)
    ds.attrs['site_longitude'] = 9.8458 
    ds.attrs['site_latitude'] = 46.8143 
    ds.attrs['site_elevation'] = 1590
    out['ds_original'] = ds.copy()
    dsmet = xr.open_dataset(fnmet)
    out['dsmet'] = dsmet
    gdd = atmspec.CombinedGlobalDiffuseDirect(ds.copy(), verbose = verbose)
    gdd.dataset['channel_wavelength'] = gdd.dataset.channel_wavelength.astype(float) #error in processing upstream, fix it in future versions!
    # the following line is causing the 1625 to drop out
    gdd = gdd.apply_calibration_langley(langley_calibration)
    ### Moving to direct
    dni = gdd.direct_normal_irradiation
    dni.dataset.attrs['serial_no'] = dni.dataset.sn_mfrsr
    out['dni_inst'] =  dni
    dni.verbose = True
    
    # met data
    dni.met_data = dsmet
    
    #lookuptable for precipitagble water
    # dni.precipitable_water = fnlut
    
    # ozone
    # dni.ozone_data = 300
    ozone = dsmet.ozone.where(dsmet.ozone != -99.999)
    ozone = ozone.interpolate_na('time', method = 'nearest', fill_value = 'extrapolate')
    dni.ozone_data = ozone
    # precipitable water
    # dni.precipitable_water_varname = 'precipitable_water_aeronet''
    if pwv_source == 'aeronet':
        pwv = dsmet.precipitable_water_aeronet/10
        dni.precipitable_water = pwv.where(pwv >= 0)
    elif pwv_source == '940':
        dni.precipitable_water = ds_lut
        dni.skip_1625_channel = True
        dni.precipitable_water      # initiates the calculation of pwv
        out['tp1'] = dni.dataset.copy()
        # reset AOD so it is calculated with 1625
        dni.dataset = dni.dataset.drop_vars('aod')
        dni.skip_1625_channel = False
    else:
        assert(False), 'not an option'

    # retrieve it all
    dni.dataset.attrs['serial_no'] = serial_no #when looking for filters it will need the serial number
    dni.absorption_correction_coeff_1625 =  '1625nm_absorption_correction_coefficience.nc'
    dni.aod #this will trigger the retrieval and populate the raw_data
    out['tp2'] = dni.dataset.copy()
    # create cloud flag
    aod = atmcop.AOD_AOT(dni.dataset)
    cm = aod.cloudmask.cloudmask_michalsky
    cm = cm.where(~ np.isnan(cm), 2).astype('int8')
    cm.attrs.update({
        "long_name": "cloud detection flag",
        "standard_name": "status_flag",
        "units": "1",
        "flag_values": '0, 1, 2',
        "flag_meanings": "no_cloud_detected cloud_detected algorithm_not_run",
        "description": (
            "0 = no cloud detected; 1 = cloud detected; "
            "2 = algorithm could not be evaluated"
        ),
    })
    out['cloud_flag'] = cm.copy()
    dni.dataset['cloud_flag'] = cm

    # aod uncertainties
    am = dni.sun_position.airmass
    aoduc = langley_calibration.OD_uncertainty/am
    aoduc = aoduc.rename({'wavelength': 'channel'})
    
    # format the file
    drop = [#'alltime',
            'toa_spectral_irradiance','ozone_absorption_spectrum', 'ozon_absoption_by_channel', 'wavelength', 
            # 'direct_horizontal'
            # 'quantile'
           ]
    prod = dni.dataset.drop_vars(drop)

    # remove the 940 channel
    prod[aod] = prod.aod.where(prod.channel != 940) 
    # prod = prod.sel(channel=[i for i in ds.channel.values if i != 940])
    # prod = prod.where(prod.channel != 940) 
    
    od1625 = dni.od_co2_ch4_h2o.sel(channel = 1625, drop = True)
    prod['od_1625nm_co2'] = od1625.co2
    prod['od_1625nm_ch4'] = od1625.ch4
    prod['od_1625nm_h2o'] = od1625.h2o_5cm

    prod['aod_uncertainty'] = aoduc
    prod.aod_uncertainty.attrs['description'] = 'Absolute AOD uncertainty based on Langley calibration. airmass^-1  ((V0_std / V0 * osub) + 0.005). osub: one-sided upper bound factor with a 95% confidence, mostly relevant for small number of langleys.'
    dni.dataset['aod_uncertainty'] = prod['aod_uncertainty']
    prod['airmass'] = am
    
    #####
    # angstrom exp
    prod['angstrom_exponent'] = dni.angstrom_exponent
    prod['angstrom_exponent_uncertainty'] = dni.angstrom_exponent_uncertainty
    prod['angstrom_turbidity_coefficient'] = dni.angstrom_turbidity_coefficient
    #####
    # order variables
    prod = prod[["aod",
                 "aod_uncertainty",
                 "angstrom_exponent",
                 "angstrom_exponent_uncertainty",
                 "angstrom_turbidity_coefficient", 
                 "cloud_flag",
                "precipitable_water",
                "transmission",
                "global_horizontal",
                "diffuse_horizontal",
                "direct_normal",
                "od_rayleigh",
                "od_ozone",
                "od_1625nm_co2",
                "od_1625nm_ch4",
                "od_1625nm_h2o",
                "channel_wavelength",
                "cosine_calibraion_direct",
                "solar_zenith_angle",
                "solar_azimuth_angle",
                 "airmass",
                "pressure",
                "temperature",
                "ozone_data",]]
    
    # drop some artefacts
    drop = [
            # 'quantile'
           ]
    prod = prod.drop_vars(drop)

    
    
    # add some attributes
    attrs = dict(title = "MFRSR calibrated spectral irradiance, aerosol optical depth, and precipitable water vapor",
                 summary = f"Calibrated spectral irradiances and retrieval products from MFRSR serial number {serial_no} during the 2025 FRC campaign at Davos / PMOD-WRC.",
                 description = 'Spectral AOD, downwelling fluxes, and precipitable water from NOAA/GRAD MFRSR instruments during 2025 FRC in Davos',
                 Conventions = "CF-1.11, ACDD-1.3",
                 institution = "NOAA Global Monitoring Laboratory / Global Radiation, Aerosols, and Clouds Division",
                 project = "2025 FRC",
                 observatory_name = "Physikalisch-Meteorologisches Observatorium Davos / World Radiation Center",
                 observatory_id = "PMOD-WRC",
                 site_id = prod.attrs['site'],
                 site_name = prod.attrs['site_name'],
                 site_longitude = f'{prod.attrs['site_longitude']:0.6f}',
                 site_latitude = f'{prod.attrs['site_latitude']:0.6f}',
                 site_elevation = f'{prod.attrs['site_elevation']:0.0f}',
                 instrument = "Multifilter Rotating Shadowband Radiometer",
                 instrument_serial_no = prod.attrs['serial_no'],
                 # instrument = prod.attrs['instrument'],
                 input_files = ', '.join([fn.as_posix(), fnmet.as_posix(), fnlut.attrs['path2file'], langley_calibration.path2file]),
                 processing_timestamp = f'{pd.Timestamp.now()}',
                 product_version = version
                )          
    
    prod.attrs = attrs


    # dni.toa_spectral_irradiance # this is already adjusted to sun earth distan

    prod = prod.rename({'datetime': 'time'})
    
    irradiance_comment = (
        "Instrument calibration was performed using Langley-derived top-of-atmosphere "
        "(extraterrestrial) signals. Irradiance units were assigned by scaling the "
        "Langley calibration to bandpass-weighted top-of-atmosphere solar irradiances "
        "computed from the ASTM E490-00a AM0 reference spectrum."
    )
    
    attrs = dict(long_name = "spectral atmospheric transmission",
                 units = "1",
                 comment = "Direct-beam atmospheric transmission derived from langley calibrated MFRSR measurements."
                )
    
    prod.transmission.attrs = attrs
    
    attrs = dict(long_name = "spectral global horizontal irradiance",
                 units = "W m-2 nm-1",
                 comment =irradiance_comment
                )
    prod.global_horizontal.attrs = attrs
    prod.global_horizontal.attrs
    
    attrs = dict(long_name = "spectral diffuse horizontal irradiance",
                 units = "W m-2 nm-1",
                 comment = irradiance_comment
                )
    prod.diffuse_horizontal.attrs = attrs
    prod.diffuse_horizontal.attrs
    
    attrs = dict(long_name = "spectral direct normal irradiance",
                 units = "W m-2 nm-1",
                 comment = irradiance_comment
                )
    prod.direct_normal.attrs = attrs
    prod.direct_normal.attrs
    
    attrs = dict(long_name = "spectral aerosol optical depth",
                 standard_name = "atmosphere_optical_thickness_due_to_ambient_aerosol_particles",
                 units = "1",
                 ancillary_variables = "aod_uncertainty cloud_flag",
                 comment = "AOD after correction for Rayleigh scattering and gaseous absorption from O3, CH4, CO2, and H2O."
                )
    prod.aod.attrs = attrs
    prod.aod.attrs
    
    attrs = dict(long_name = 'absolute uncertainty of aerosol optical depth',
                 units = "1",
                 comment = "One-sigma aerosol optical depth uncertainty estimated from the variability among the applicable Langley calibrations, with a small-sample correction applied.")
    prod.aod_uncertainty.attrs = attrs
    
    od_correction_comment = (
        "Modeled optical depth correction term calculated from auxiliary data and "
        "instrument channel properties; this variable is not a retrieved geophysical product."
    )
    
    attrs = dict(long_name = "Rayleigh optical depth correction",
                 units = "1",
                 comment = od_correction_comment)
    prod.od_rayleigh.attrs = attrs
    
    attrs = dict(long_name = "ozone optical depth correction",
                 units = "1",
                 comment = od_correction_comment)
    prod.od_ozone.attrs = attrs
    
    attrs = dict(long_name = "water vapor optical depth correction at 1625 nm",
                 units = "1",
                 comment = od_correction_comment)
    prod.od_1625nm_h2o.attrs = attrs
    
    attrs = dict(long_name = "carbon dioxide optical depth correction at 1625 nm",
                 units = "1",
                 comment = od_correction_comment)
    prod.od_1625nm_co2.attrs = attrs
    
    attrs = dict(long_name = "methane optical depth correction at 1625 nm",
                 units = "1",
                 comment = od_correction_comment)
    prod.od_1625nm_ch4.attrs = attrs
    
    attrs = dict(long_name = "effective center wavelength",
                 units = "nm",
                 comment = "Effective center wavelength for each MFRSR channel.",
                )
    prod.channel_wavelength.attrs = attrs
    
    attrs = dict(long_name = "nominal MFRSR channel wavelength",
                 units = "nm")
    prod.channel.attrs = attrs
    
    prod = prod.rename_vars({'ozone_data':'total_column_ozone' })
    
    attrs = dict()
    prod.total_column_ozone.attrs

    prod.aod.loc[{'channel':940}] = np.nan
    prod.aod_uncertainty.loc[{'channel':940}] = np.nan
    
    out['product'] = prod 
    return out

# %%
pl.Path(f'{prefix}/nfs/grad/Inst/MFR/Campaign/frc/2025/mfrsr/{serial_no}.cal/v0.2/2025/dav_mfrsr_cosinecorrected_20251014.nc')
# Out:
# PosixPath('/Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/2025/mfrsr/649.cal/v0.2/2025/dav_mfrsr_cosinecorrected_20251014.nc')

# %%
# Test
out = make_product(fn = pl.Path(f'{prefix}/nfs/grad/Inst/MFR/Campaign/frc/2025/mfrsr/{serial_no}.cal/v0.2/2025/dav_mfrsr_cosinecorrected_20251014.nc'),
                 fnmet = pl.Path(f'{prefix}/nfs/grad/campaign/frc/2025/MetaData.netcdf/frc-vi_metadata_20251014_preliminary.nc'),
                 fnlut =  ds_lut,
                 langley_calibration = V0,
                 serial_no = f'{serial_no}',
                 version = version)
# dni = out
# Out:
# Renaming time coordinate to datetime for ozone data.
# Retrieving precipitable water from 940nm channel using lookup table.
# Calculating transmission.
# Calculating transmission using the provided top of atmosphere spectral irradiance.
# Calculating ozone optical depth for each channel.
# /Users/htelg/miniconda3/envs/py13/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /Users/htelg/miniconda3/envs/py13/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# /Users/htelg/prog/atm-py/atmPy/radiation/retrievals/spectral_irradiance.py:1168: FutureWarning: dropping variables using `drop` is deprecated; use drop_vars.
#   ozon2bychannel = ozon2bychannel.drop('wavelength')
# ...

# %%
prod = out['product']
dni = out['dni_inst']
ds = out['product']

# %%
dni.angstrom_turbidity_coefficient.plot.line(x = 'datetime')
dni.aod.sel(channel = 870).plot(color = 'black')
a = plt.gca()
a.set_ylim(0,0.02)
# Out:
# (0.0, 0.02)

# %%
prod.angstrom_exponent.plot.line(x = 'time')

# %%
dni.angstrom_exponent_uncertainty.sel(angstrom_exponent_pair = '500_870').plot()

# %%
wls = [
    415,
    500,
    670,
    870,
    1625
]
alpha = 0.4
f,a = plt.subplots()
for wl in wls:
    aod = ds.aod.sel(channel = wl)
    aod.plot(ax = a, label = wl)
    col = a.get_lines()[-1].get_color()
    if 1:
        uc = ds.aod_uncertainty.sel(channel = wl)
        a.fill_between(aod.time, aod - uc, aod + uc, alpha = alpha, zorder = 0, color = col, linewidth = 0)
    # break
        
a.legend()
a.set_ylim(-0.01, 0.07)
# Out:
# (-0.01, 0.07)

# %% [markdown]
# # Workplan

# %%
'/Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/2025/mfrsr/.cal/v0.1/'
# Out:
# '/Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/2025/mfrsr/.cal/v0.1/'

# %%
dfmfrsr = pd.DataFrame(p2fld_mfrsr.glob('*.nc'), columns=['p2f_mfrsr_in'])
dfmfrsr.index = dfmfrsr.apply(lambda row: pd.to_datetime(row.p2f_mfrsr_in.name.split('_')[-1].replace('.nc','')), axis =1)

dfmet = pd.DataFrame(p2fld_met.glob('*.nc'), columns=['p2f_met'])
dfmet.index = dfmet.apply(lambda row: pd.to_datetime(row.p2f_met.name.split('_')[-2]), axis = 1)

mp = pd.concat([dfmfrsr,dfmet], axis = 1)
mp['p2f_out'] = mp.apply(lambda row: p2fld_out.joinpath(f'aod_frc_{serial_no}_v{version}_{row.name.strftime('%Y%m%d')}.nc'), axis = 1)
# Out:
# /var/folders/f4/dl3whmyd1rj_9smbyhmyqyj1h26f40/T/ipykernel_97553/898005777.py:7: Pandas4Warning: Sorting by default when concatenating all DatetimeIndex is deprecated.  In the future, pandas will respect the default of `sort=False`. Specify `sort=True` or `sort=False` to silence this message. If you see this warnings when not directly calling concat, report a bug to pandas.
#   mp = pd.concat([dfmfrsr,dfmet], axis = 1)

# %%
wp = mp.dropna()
if not overwrite:
    wp = wp[~wp.apply(lambda row: row.p2f_out.exists(), axis = 1)]

# %%
wp
# Out:
#                                                  p2f_mfrsr_in  \
# 2025-09-25  /Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/20...
# 2025-09-26  /Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/20...
# 2025-09-27  /Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/20...
# 2025-09-28  /Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/20...
# 2025-09-29  /Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/20...
# 2025-10-01  /Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/20...
# 2025-10-02  /Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/20...
# 2025-10-03  /Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/20...
# 2025-10-04  /Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/20...
# 2025-10-06  /Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/20...
# 2025-10-07  /Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/20...
# 2025-10-08  /Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/20...
# 2025-10-09  /Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/20...
# 2025-10-10  /Users/htelg/nfs/grad/Inst/MFR/Campaign/frc/20...
# ...

# %%
wp.iloc[0].p2f_out
# Out:
# PosixPath('/Users/htelg/nfs/grad/campaign/frc/2025/AOD/US_NOAA_MFR_9/netcdf/v1.0/aod_frc_649_v1.0_20250925.nc')

# %% [markdown]
# # work it

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
overwrite = True
for idx, row in wp.iterrows():
    print('.', end = '')
    if row.p2f_out.exists():
        if not overwrite:
            continue
        else:
            row.p2f_out.unlink()
        

    try:
        out = make_product(fn = row.p2f_mfrsr_in,
                 fnmet = row.p2f_met,
                 fnlut =  ds_lut,
                 langley_calibration = V0,
                 serial_no = serial_no,
                 version = version)        
        prod = out['product']
        row.p2f_out.parent.mkdir(parents=True, exist_ok=True)
        prod.to_netcdf(row.p2f_out)
        print(':', end = '')
    except:
        raise
        print('something went wrong')
        continue
# Out:
# .Renaming time coordinate to datetime for ozone data.
# Retrieving precipitable water from 940nm channel using lookup table.
# Calculating transmission.
# Calculating transmission using the provided top of atmosphere spectral irradiance.
# Calculating ozone optical depth for each channel.
# :.
# Renaming time coordinate to datetime for ozone data.
# Retrieving precipitable water from 940nm channel using lookup table.
# Calculating transmission.
# Calculating transmission using the provided top of atmosphere spectral irradiance.
# Calculating ozone optical depth for each channel.
# :.Renaming time coordinate to datetime for ozone data.
# Retrieving precipitable water from 940nm channel using lookup table.
# Calculating transmission.
# Calculating transmission using the provided top of atmosphere spectral irradiance.
# Calculating ozone optical depth for each channel.
# :.Renaming time coordinate to datetime for ozone data.
# ...

# %%
prod.aod.plot.line(x = 'time')

# %%
plt.gcf().show()

# %%
p2fl = list(p2fld_out.glob('*'))
p2fl.sort()
